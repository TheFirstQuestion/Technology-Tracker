# %% [markdown]
# https://www.machinelearningnuggets.com/logistic-regression/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report

# %%
#/* ########################### Read in the data ########################## */
df = pd.read_csv(
    "./data/TT-2018-H1-REDACTED-excluding-Postcodes.csv",
    delimiter=",",
    encoding_errors="replace",
)
df.dataframeName = "2018"

#/* ########################### Clean up the data ########################## */
# Rename columns
df = df.rename(columns={
  "ISF": "age", 
  "ISI": "householdSize",
  "ISJ": "numChildrenInHousehold"
})

# Remove participants with empty age
df = df.dropna(subset=["age"])
df = df[df.age != " "]

# Make dummy columns
df['isRetired'] = np.where(df['SGC'] == "Not working (i.e. under 8hrs/wk) - retired", 1, 0)
df['isHomebound'] = np.where(df['SGF'] == "Not working (i.e. under 8hrs/wk) - housewife/ disabled/ other", 1, 0)
df['isFemale'] = np.where(df['SE'] == "Female", 1, 0)
df['isRural'] = np.where(df['URBAN'] == "Rural", 1, 0)

df['nationalityEnglish'] = np.where(df['QZ10'] == "English", 1, 0)
df['nationalityScottish'] = np.where(df['QZ10'] == "Scottish", 1, 0)
df['nationalityWelsh'] = np.where(df['QZ10'] == "Welsh", 1, 0)
df['nationalityNorthIrish'] = np.where(df['QZ10'] == "Northern Irish", 1, 0)
df['nationalityBritish'] = np.where(df['QZ10'] == "British", 1, 0)
df['nationalityIrish'] = np.where(df['QZ10'] == "Irish", 1, 0)
df['nationalityOther'] = np.where(df['QZ10'] == "Other", 1, 0)
nationalities = ["nationalityEnglish", "nationalityScottish", "nationalityWelsh", "nationalityNorthIrish", "nationalityBritish", "nationalityIrish", "nationalityOther"]

df['raceWhite'] = np.where(df['QZ2XG'] == "TOTAL WHITE", 1, 0)
df['raceMixedWhiteBlackCaribbean'] = np.where(df['QZ2XH'] != "Not", 0, 1)
df['raceMixedWhiteBlackAfrican'] = np.where(df['QZ2XI'] != "Not", 0, 1)
df['raceMixedWhiteAsian'] = np.where(df['QZ2XJ'] != "Not", 0, 1)
df['raceMixedOther'] = np.where(df['QZ2XK'] != "Not", 0, 1)
df['raceIndian'] = np.where(df['QZ2XM'] != "Not", 0, 1)
df['racePakistani'] = np.where(df['QZ2XN'] != "Not", 0, 1)
df['raceBangladeshi'] = np.where(df['QZ2XO'] != "Not", 0, 1)
df['raceAsianOther'] = np.where(df['QZ2XP'] != "Not", 0, 1)
df['raceBlackCaribbean'] = np.where(df['QZ2XR'] != "Not", 0, 1)
df['raceBlackAfrican'] = np.where(df['QZ2XS'] != "Not", 0, 1)
df['raceBlackOther'] = np.where(df['QZ2XT'] != "Not", 0, 1)
df['raceMiddleEastern'] = np.where(df['QZ2XV'] != "Not", 0, 1)
df['raceChinese'] = np.where(df['QZ2XY'] != "Not", 0, 1)
df['raceOther'] = np.where(df['QZ2XZ'] != "Not", 0, 1)
df['raceRefused'] = np.where(df['QZ2XAB'] != "Not", 0, 1)
races = ["raceWhite", 'raceMixedWhiteBlackCaribbean', 'raceMixedWhiteBlackAfrican', 'raceMixedWhiteAsian', 'raceMixedOther', 'raceIndian', 'racePakistani', 'raceBangladeshi', 'raceAsianOther', 'raceBlackCaribbean', 'raceBlackAfrican', 'raceBlackOther', 'raceMiddleEastern', 'raceChinese', 'raceOther', 'raceRefused']

df['abilityBreathless'] = np.where(df['QZ5AA'] != "Not", 0, 1)
df['abilityVision'] = np.where(df['QZ5AB'] != "Not", 0, 1)
df['abilityCommunicating'] = np.where(df['QZ5AC'] != "Not", 0, 1)
df['abilityHearing'] = np.where(df['QZ5AD'] != "Not", 0, 1)
df['abilityWalking'] = np.where(df['QZ5AF'] != "Not", 0, 1)
df['abilityWheelchair'] = np.where(df['QZ5AE'] != "Not", 0, 1)
df['abilityReach'] = np.where(df['QZ5AG'] != "Not", 0, 1)
df['abilityMentalHealth'] = np.where(df['QZ5AH'] != "Not", 0, 1)
df['abilityDyslexia'] = np.where(df['QZ5AI'] != "Not", 0, 1)
df['abilityOther'] = np.where(df['QZ5AJ'] != "Not", 0, 1)
abilities = ["abilityBreathless", "abilityVision", "abilityCommunicating", "abilityHearing", "abilityWalking", "abilityWheelchair", "abilityReach", "abilityMentalHealth", "abilityDyslexia", "abilityOther"]

incomeSwitch = {
  "Up to �199 per week/ �10,399 per year": 1,
  "From �200 to �299 per week/ �10,400 to �15,599 per year": 2,
  "From �300 to �499 per week/ �15,600 to �25,599 per year": 3,
  "From �500 to �699 per week/ �26,000 to �36,399 per year": 4,
  "From �700 to �999 per week/ �36,400 to �51,999 per year": 5,
  "�1,000 per week and above/ �52,000 and above per year": 6,
  "Don't know/ Refused": 3.5
}

incomeCol = []
for i, val in enumerate(df['QZ13']):
  incomeCol.append(incomeSwitch[val])
df["income"] = incomeCol


classCol = []
for i, row in df.iterrows():
  if row['BKSEGA'] != "Not":
    classCol.append(1)
  elif row['BKSEGB'] != "Not":
    classCol.append(2)
  elif row['BKSEGC'] != "Not":
    classCol.append(3)
  elif row['BKSEGD'] != "Not":
    classCol.append(4)
  else:
    classCol.append(2.5)
df["class"] = classCol


df['accessHomeInternet'] = np.where(df['QE2'] != "No do not have access at home", 1, 0)
df['accessLandline'] = np.where(df['QCHECKA'] != "Landline phone", 1, 0)
df['accessMobile'] = np.where(df['QCHECKB'] != "Mobile phone", 1, 0)
df['accessBroadbandFixed'] = np.where(df['QCHECKC'] != "Fixed broadband internet access", 1, 0)
df['accessBroadbandMobile'] = np.where(df['QCHECKD'] != "Mobile broadband internet access", 1, 0)
df['accessNarrowband'] = np.where(df['QCHECKE'] != "Narrowband internet access", 1, 0)
df['accessTVPaid'] = np.where(df['QCHECKF'] != "TV service with additional channels you pay to receive", 1, 0)
accessOutputColumns = ["accessHomeInternet", "accessLandline", "accessMobile", "accessBroadbandFixed", "accessBroadbandMobile", "accessNarrowband", "accessTVPaid"]


df['usesDVDPlayer'] = np.where(df['QB2K'] == "Not", 0, 1)
df['usesIpod'] = np.where(df['QB2C'] == "Not", 0, 1)
df['usesEbook'] = np.where(df['QB2D'] == "Not", 0, 1)

df['usesGamesTV'] = np.where(df['QB2A'] == "Not", 0, 1)
df['usesGamesHandheld'] = np.where(df['QB2B'] == "Not", 0, 1)
df['usesGamesVR'] = np.where(df['QB2J'] == "Not", 0, 1)

df['usesSmartWatch'] = np.where(df['QB2H'] == "Not", 0, 1)
df['usesSmartSpeaker'] = np.where(df['QB2I'] == "Not", 0, 1)

# df['usesMobile'] = np.where(df['QD2'] == "No mobiles in household", 0, 1)
df['usesSmartphone'] = np.where(df['QD24B'] == "Yes", 1, 0)

df['usesRadio'] = np.where(df['QP5G'] == "ANY 'ACTIVE' RADIO SETS IN THE HOME", 1, 0)
df['usesRadioDigital'] = np.where(df['QP7H'] == "ANY 'ACTIVE' DIGITAL RADIOS IN THE HOME", 1, 0)

df['usesHomeInternet'] = np.where(df['QE2'] == "Yes - have access and use at home", 1, 0)
df['usesTablet'] = np.where(df['QE36'] == "Yes", 1, 0)

usageOutputColumns = ["usesDVDPlayer", "usesGamesTV", "usesIpod", "usesEbook", "usesGamesHandheld", "usesSmartWatch", "usesSmartSpeaker", "usesGamesVR",  "usesSmartphone", "usesRadio", "usesRadioDigital", "usesHomeInternet", "usesTablet"]
# "usesMobile",

# Convert to proper data types
df["age"] = pd.to_numeric(df["age"])
df["numChildrenInHousehold"] = pd.to_numeric(df["numChildrenInHousehold"])

# %%
# Create dataframe of just seniors
seniorsDF = df.query("age >= 65")

nPopulation = df.shape[0]
nSeniors = seniorsDF.shape[0]

print(f'population of {nPopulation}, {nSeniors} seniors')
print(f'({100 * (nSeniors / nPopulation):.0f}%)')

# Distribution of age in the dataset
sns.displot(x='age', data=df, color='red', kde=True)
# Out:
# population of 3657, 833 seniors
# (23%)

# %%
# Counts of usage for each output variable (population and seniors side-by-side)

# Perform permutation test -- does the senior usage match the population usage for each output column?
from scipy.stats import permutation_test

# This is our statistic of interest -- difference between the two samples
def statistic(sample1, sample2):
  return sample1.sum() - sample2.sum()

# p value correction -- pick alpha to be really strict because testing multiple p-values means more chances of one going

# define figure size
sns.set(rc={"figure.figsize":(10, 5), "figure.max_open_warning": False})

for col in usageOutputColumns:
  fig, axes = plt.subplots(1, 2)
  # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.permutation_test.html
  pValue = permutation_test((df[col], seniorsDF[col]), statistic, permutation_type='independent', alternative='two-sided').pvalue
  fig.suptitle(f'{col} (p={pValue:.4f})')

  plotPopulation = sns.countplot(x=col, data=df, ax=axes[0])
  plotPopulation.set_title("Population")
  plotPopulation.set_xlabel("")
  plotPopulation.set_ylabel("count")
  # Set y axis to range from 0 to all, so scaling is comparable
  plotPopulation.set_ylim(0, nPopulation)

  plotSeniors = sns.countplot(x=col, data=seniorsDF, ax=axes[1])
  plotSeniors.set_title("Seniors")
  plotSeniors.set_xlabel("")
  plotSeniors.set_ylabel("count")
  plotSeniors.set_ylim(0, nSeniors)

# %%
# Select independent variables
indCols = ["age", "isRetired", "isHomebound", "numChildrenInHousehold", "householdSize", "isFemale", "isRural", "income", "class", *nationalities, *abilities, *races]
X = df.loc[:, indCols]

# %%
# Correlation Matrix (ability)
rnCols = ["age", "isRetired", "isHomebound", *abilities]

# calculate the correlation matrix
corr = df.corr(numeric_only=True).loc[[*rnCols, *usageOutputColumns], [*rnCols, *usageOutputColumns]]

# define figure size
sns.set(rc={"figure.figsize":(20, 20)})

# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, fmt='.1f', vmin=-1, vmax=1, cmap=(sns.diverging_palette(0,240, as_cmap=True)))
# Out:
# <AxesSubplot:>

# %%
# Correlation Matrix (race + nationality columns)
rnCols = [*races, *nationalities]

# calculate the correlation matrix
corr = df.corr(numeric_only=True).loc[[*rnCols, *usageOutputColumns], [*rnCols, *usageOutputColumns]]

# define figure size
sns.set(rc={"figure.figsize":(20, 20)})

# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, fmt='.1f', vmin=-1, vmax=1, cmap=(sns.diverging_palette(0,240, as_cmap=True)))
# Out:
# <AxesSubplot:>

# %%
# Correlation Matrix (socioeconomic columns)
seCols = ["income", "class"]

# calculate the correlation matrix
corr = df.corr(numeric_only=True).loc[[*seCols, *usageOutputColumns], [*seCols, *usageOutputColumns]]

# define figure size
sns.set(rc={"figure.figsize":(14, 14)})

# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, fmt='.1f', vmin=-1, vmax=1, cmap=(sns.diverging_palette(0,240, as_cmap=True)))
# Out:
# <AxesSubplot:>

# %%
# Correlation Matrix (demographic columns)
demCols = ["age", "isRetired", "isHomebound", "numChildrenInHousehold", "householdSize", "isFemale", "isRural"]

# calculate the correlation matrix
corr = df.corr(numeric_only=True).loc[[*demCols, *usageOutputColumns], [*demCols, *usageOutputColumns]]

# define figure size
sns.set(rc={"figure.figsize":(14, 14)})

# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, fmt='.1f', vmin=-1, vmax=1, cmap=(sns.diverging_palette(0,240, as_cmap=True)))
# Out:
# <AxesSubplot:>

# %%
# Correlation Matrix (all columns)
# calculate the correlation matrix
corr = df.corr(numeric_only=True).loc[[*indCols, *usageOutputColumns], [*indCols, *usageOutputColumns]]

# define figure size
sns.set(rc={"figure.figsize":(40, 40)})

# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, fmt='.1f', vmin=-1, vmax=1, cmap=(sns.diverging_palette(0,240, as_cmap=True)))
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from pprint import pprint

# df or seniorsDF
df_to_test = df

# Train on everyone
# check training accuracy and testing accuracy
# if I train model and can't get past 50% on some classes -- no point in using the model
# focus on the ones I can successfully predict
# look at AUROC (and AUPRC for imbalanced class) -- can calculate for a random model
# baseline: shuffle the labels and see how they predict the unshuffled labels (baseline random)
# compare model to baseline -- order of magnitude better
# do all of this and THEN subset to old people
# I will have predictions for old people if looking at everyone
# want to get the thetas for each variable
# super worth doing exploratory data analysis -- for every variable, is there a clear correlation
# tells u what ur model should learn
# if the correlations are low model will be bad
# if they are high no reason model should be bad
# make a bar plot and name every feature and what the theta is (maybe absolute value)
# increase max iterations until you plateau
# step size: smaller is slower training, but too big would keep from (start 10^-5)
# have to optimize those two jointly


weights = {}

# Train a model for each output
for col in usageOutputColumns:
  # Get dependent variables
  y = df_to_test.loc[:, col]

  # Split into testing and training sets
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

  # Make the model
  classifier = LogisticRegression(solver="liblinear", max_iter=10000, class_weight="balanced", tol=0.00001)
  classifier.fit(X_train, y_train)

  # Do the prediction
  y_pred = classifier.predict(X_test)

  # Evaluate the model, using a confusion matrix heatmap
  # cf_matrix = confusion_matrix(y_test, y_pred)
  # plt.figure() # this creates a new figure on which your plot will appear
  # sns.heatmap(pd.DataFrame(cf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
  # plt.title(f'Confusion matrix for {col}', y=1.1)
  # plt.ylabel('Actual label')
  # plt.xlabel('Predicted label')
  # plt.show()

  accuracyScore = accuracy_score(y_test,y_pred) * 100
  print(f'Testing accuracy of model for {col}: {accuracyScore:.2f}%')

  # Area Under the Receiver Operating Characteristic Curve (ROC AUC)
  print(f'Testing ROC AUC for {col}: {100 * roc_auc_score(y_test, y_pred):.2f}%')


  baseRatePos = 100 * df_to_test[col].sum() / df_to_test.shape[0]
  baseRateNeg = 100 * (df_to_test.shape[0] - df_to_test[col].sum()) / df_to_test.shape[0]
  posDiff = accuracyScore - baseRatePos
  negDiff = accuracyScore - baseRateNeg
  
  if posDiff < negDiff:
    baseRate = baseRatePos
    improvement = posDiff
  else:
    baseRate = baseRateNeg
    improvement = negDiff

  print(f"base rate: {baseRate:.2f}")
  print(f"improvement: {improvement:.2f}")

  w = {}
  for i, feature in enumerate(classifier.feature_names_in_):
    w[feature] = round(classifier.coef_[0][i], 2)

  weights[col] = sorted(w.items(), key=lambda x:abs(x[1]), reverse=True)

  print("---------------------------------------------------------------------------")

pprint(weights)
# Out:
# Testing accuracy of model for usesDVDPlayer: 57.47%
# Testing ROC AUC for usesDVDPlayer: 57.31%
# base rate: 50.18
# improvement: 7.29
# ---------------------------------------------------------------------------
# Testing accuracy of model for usesGamesTV: 74.23%
# Testing ROC AUC for usesGamesTV: 75.67%
# base rate: 78.78
# improvement: -4.55
# ---------------------------------------------------------------------------
# Testing accuracy of model for usesIpod: 64.39%
# Testing ROC AUC for usesIpod: 65.60%
# base rate: 82.72
# improvement: -18.33
# ---------------------------------------------------------------------------
# Testing accuracy of model for usesEbook: 60.47%
# Testing ROC AUC for usesEbook: 63.38%
# base rate: 82.80
# improvement: -22.33
# ---------------------------------------------------------------------------
# Testing accuracy of model for usesGamesHandheld: 69.95%
# Testing ROC AUC for usesGamesHandheld: 70.96%
# base rate: 93.52
# improvement: -23.57
# ---------------------------------------------------------------------------
# Testing accuracy of model for usesSmartWatch: 66.85%
# Testing ROC AUC for usesSmartWatch: 68.49%
# base rate: 86.82
# improvement: -19.97
# ---------------------------------------------------------------------------
# Testing accuracy of model for usesSmartSpeaker: 63.11%
# Testing ROC AUC for usesSmartSpeaker: 62.89%
# base rate: 90.78
# improvement: -27.67
# ---------------------------------------------------------------------------
# Testing accuracy of model for usesGamesVR: 73.22%
# Testing ROC AUC for usesGamesVR: 67.52%
# base rate: 97.70
# improvement: -24.48
# ---------------------------------------------------------------------------
# Testing accuracy of model for usesSmartphone: 78.23%
# Testing ROC AUC for usesSmartphone: 79.00%
# base rate: 75.75
# improvement: 2.49
# ---------------------------------------------------------------------------
# Testing accuracy of model for usesRadio: 65.94%
# Testing ROC AUC for usesRadio: 66.63%
# base rate: 56.44
# improvement: 9.50
# ---------------------------------------------------------------------------
# Testing accuracy of model for usesRadioDigital: 59.11%
# Testing ROC AUC for usesRadioDigital: 60.17%
# base rate: 63.66
# improvement: -4.55
# ---------------------------------------------------------------------------
# Testing accuracy of model for usesHomeInternet: 74.41%
# Testing ROC AUC for usesHomeInternet: 74.59%
# base rate: 83.70
# improvement: -9.29
# ---------------------------------------------------------------------------
# Testing accuracy of model for usesTablet: 62.66%
# Testing ROC AUC for usesTablet: 62.78%
# base rate: 52.56
# improvement: 10.10
# ---------------------------------------------------------------------------
# {'usesDVDPlayer': [('raceMixedOther', -1.24),
#                    ('raceBlackCaribbean', 1.21),
#                    ('raceBlackAfrican', 0.9),
#                    ('raceWhite', 0.73),
#                    ('raceRefused', -0.72),
#                    ('raceBlackOther', -0.67),
#                    ('nationalityIrish', -0.64),
#                    ('raceMixedWhiteBlackAfrican', -0.64),
#                    ('abilityHearing', 0.58),
#                    ('nationalityNorthIrish', -0.55),
#                    ('raceMiddleEastern', 0.55),
#                    ('abilityOther', 0.48),
#                    ('nationalityOther', -0.46),
#                    ('nationalityWelsh', 0.43),
#                    ('nationalityBritish', 0.43),
#                    ('abilityBreathless', 0.42),
#                    ('raceOther', 0.42),
#                    ('nationalityEnglish', 0.41),
#                    ('abilityWheelchair', 0.36),
#                    ('abilityDyslexia', -0.35),
#                    ('raceChinese', -0.31),
#                    ('abilityCommunicating', -0.3),
#                    ('isFemale', -0.28),
#                    ('abilityReach', -0.25),
#                    ('abilityMentalHealth', -0.25),
#                    ('raceBangladeshi', -0.25),
#                    ('nationalityScottish', 0.23),
#                    ('abilityWalking', 0.23),
#                    ('raceIndian', -0.21),
#                    ('isRetired', -0.2),
#                    ('class', -0.2),
#                    ('raceMixedWhiteBlackCaribbean', -0.2),
#                    ('raceMixedWhiteAsian', -0.14),
#                    ('isHomebound', 0.09),
#                    ('numChildrenInHousehold', 0.08),
#                    ('householdSize', -0.08),
#                    ('isRural', 0.08),
#                    ('abilityVision', -0.05),
#                    ('racePakistani', -0.03),
#                    ('raceAsianOther', 0.03),
#                    ('age', 0.01),
#                    ('income', 0.01)],
#  'usesEbook': [('raceMixedWhiteBlackAfrican', -1.94),
#                ('raceChinese', -1.4),
#                ('racePakistani', 1.3),
#                ('raceBlackCaribbean', 1.2),
#                ('raceBlackAfrican', 1.04),
#                ('raceMixedOther', -1.01),
#                ('raceOther', 1.0),
#                ('abilityHearing', 0.87),
#                ('raceWhite', 0.77),
#                ('raceIndian', -0.75),
#                ('raceMixedWhiteBlackCaribbean', -0.73),
#                ('abilityWalking', 0.56),
#                ('raceRefused', -0.52),
#                ('class', -0.46),
#                ('nationalityOther', -0.44),
#                ('abilityReach', 0.42),
#                ('raceMixedWhiteAsian', -0.39),
#                ('raceAsianOther', 0.33),
#                ('abilityDyslexia', -0.32),
#                ('raceBangladeshi', -0.3),
#                ('raceMiddleEastern', 0.28),
#                ('abilityCommunicating', -0.27),
#                ('isFemale', 0.25),
#                ('raceBlackOther', 0.23),
#                ('nationalityIrish', 0.21),
#                ('abilityMentalHealth', -0.21),
#                ('isRural', 0.2),
#                ('abilityOther', 0.19),
#                ('nationalityNorthIrish', -0.18),
#                ('nationalityBritish', 0.18),
#                ('nationalityEnglish', 0.15),
#                ('isRetired', -0.13),
#                ('income', 0.13),
#                ('abilityVision', -0.13),
#                ('nationalityScottish', -0.11),
#                ('abilityWheelchair', 0.07),
#                ('isHomebound', 0.05),
#                ('numChildrenInHousehold', 0.04),
#                ('abilityBreathless', -0.03),
#                ('age', 0.01),
#                ('nationalityWelsh', 0.01),
#                ('householdSize', -0.0)],
#  'usesGamesHandheld': [('abilityReach', 1.57),
#                        ('raceMixedOther', -1.42),
#                        ('raceOther', 1.31),
#                        ('isHomebound', -1.13),
#                        ('raceMixedWhiteAsian', -1.12),
#                        ('abilityWheelchair', 1.02),
#                        ('abilityDyslexia', -0.93),
#                        ('raceBangladeshi', 0.89),
#                        ('raceChinese', 0.87),
#                        ('raceAsianOther', 0.81),
#                        ('abilityCommunicating', -0.79),
#                        ('raceMiddleEastern', 0.72),
#                        ('raceRefused', 0.71),
#                        ('abilityBreathless', -0.63),
#                        ('nationalityOther', -0.61),
#                        ('raceWhite', 0.59),
#                        ('abilityOther', -0.57),
#                        ('raceMixedWhiteBlackCaribbean', -0.57),
#                        ('isRetired', -0.55),
#                        ('raceBlackCaribbean', -0.55),
#                        ('raceBlackOther', 0.55),
#                        ('isFemale', -0.54),
#                        ('abilityWalking', -0.51),
#                        ('raceIndian', -0.51),
#                        ('nationalityNorthIrish', -0.5),
#                        ('nationalityBritish', 0.49),
#                        ('nationalityEnglish', 0.46),
#                        ('householdSize', 0.4),
#                        ('raceMixedWhiteBlackAfrican', -0.35),
#                        ('racePakistani', -0.28),
#                        ('nationalityWelsh', 0.26),
#                        ('isRural', 0.25),
#                        ('abilityHearing', 0.25),
#                        ('nationalityIrish', -0.23),
#                        ('numChildrenInHousehold', -0.19),
#                        ('nationalityScottish', 0.17),
#                        ('class', -0.15),
#                        ('raceBlackAfrican', 0.12),
#                        ('abilityMentalHealth', -0.08),
#                        ('age', -0.05),
#                        ('income', 0.01),
#                        ('abilityVision', -0.01)],
#  'usesGamesTV': [('isFemale', -1.64),
#                  ('raceAsianOther', -1.21),
#                  ('raceMiddleEastern', 1.18),
#                  ('raceOther', 1.07),
#                  ('abilityWheelchair', 1.05),
#                  ('raceMixedWhiteAsian', 0.91),
#                  ('raceBangladeshi', 0.77),
#                  ('raceChinese', -0.72),
#                  ('raceMixedWhiteBlackCaribbean', -0.61),
#                  ('abilityVision', 0.58),
#                  ('raceMixedWhiteBlackAfrican', -0.57),
#                  ('raceWhite', 0.51),
#                  ('raceBlackCaribbean', -0.46),
#                  ('abilityBreathless', -0.41),
#                  ('nationalityNorthIrish', -0.39),
#                  ('nationalityIrish', -0.38),
#                  ('racePakistani', 0.33),
#                  ('nationalityEnglish', 0.32),
#                  ('abilityCommunicating', 0.32),
#                  ('isHomebound', -0.31),
#                  ('isRural', 0.3),
#                  ('nationalityScottish', 0.28),
#                  ('raceIndian', 0.24),
#                  ('raceBlackAfrican', 0.24),
#                  ('nationalityBritish', 0.23),
#                  ('isRetired', 0.22),
#                  ('raceRefused', -0.19),
#                  ('householdSize', 0.17),
#                  ('abilityMentalHealth', -0.11),
#                  ('abilityOther', 0.11),
#                  ('income', 0.09),
#                  ('abilityReach', -0.09),
#                  ('age', -0.08),
#                  ('abilityWalking', 0.08),
#                  ('nationalityWelsh', -0.07),
#                  ('abilityDyslexia', -0.07),
#                  ('numChildrenInHousehold', 0.06),
#                  ('nationalityOther', 0.04),
#                  ('abilityHearing', 0.04),
#                  ('raceBlackOther', -0.04),
#                  ('class', -0.02),
#                  ('raceMixedOther', -0.01)],
#  'usesGamesVR': [('raceIndian', -2.96),
#                  ('raceWhite', 2.56),
#                  ('abilityBreathless', 2.1),
#                  ('raceMixedWhiteAsian', -2.05),
#                  ('abilityWalking', -1.65),
#                  ('abilityOther', 1.4),
#                  ('nationalityWelsh', -1.28),
#                  ('abilityHearing', 1.21),
#                  ('nationalityNorthIrish', -1.02),
#                  ('isRetired', 0.9),
#                  ('abilityWheelchair', 0.87),
#                  ('isFemale', -0.7),
#                  ('abilityMentalHealth', 0.68),
#                  ('abilityCommunicating', 0.62),
#                  ('raceAsianOther', -0.59),
#                  ('abilityVision', -0.58),
#                  ('nationalityIrish', 0.57),
#                  ('isRural', 0.56),
#                  ('abilityReach', -0.56),
#                  ('nationalityEnglish', 0.48),
#                  ('income', 0.45),
#                  ('racePakistani', 0.42),
#                  ('nationalityOther', 0.4),
#                  ('raceBlackOther', -0.32),
#                  ('householdSize', 0.31),
#                  ('raceRefused', -0.31),
#                  ('raceBlackAfrican', 0.28),
#                  ('raceMixedOther', -0.26),
#                  ('nationalityBritish', 0.23),
#                  ('raceBlackCaribbean', -0.19),
#                  ('raceOther', 0.15),
#                  ('class', -0.14),
#                  ('raceMiddleEastern', -0.13),
#                  ('numChildrenInHousehold', 0.1),
#                  ('abilityDyslexia', -0.08),
#                  ('age', -0.07),
#                  ('raceBangladeshi', -0.06),
#                  ('raceMixedWhiteBlackCaribbean', 0.05),
#                  ('raceMixedWhiteBlackAfrican', -0.05),
#                  ('isHomebound', 0.04),
#                  ('nationalityScottish', 0.02),
#                  ('raceChinese', 0.02)],
#  'usesHomeInternet': [('raceMixedWhiteAsian', 2.33),
#                       ('raceMixedOther', -1.29),
#                       ('abilityDyslexia', -1.02),
#                       ('raceIndian', -0.81),
#                       ('raceWhite', 0.73),
#                       ('raceRefused', -0.7),
#                       ('isRetired', -0.69),
#                       ('raceAsianOther', -0.68),
#                       ('raceChinese', -0.62),
#                       ('abilityReach', -0.61),
#                       ('raceMiddleEastern', 0.61),
#                       ('abilityMentalHealth', 0.58),
#                       ('raceBlackCaribbean', -0.57),
#                       ('raceMixedWhiteBlackAfrican', 0.56),
#                       ('raceOther', -0.55),
#                       ('abilityBreathless', 0.54),
#                       ('householdSize', 0.51),
#                       ('abilityWheelchair', 0.48),
#                       ('raceMixedWhiteBlackCaribbean', 0.48),
#                       ('income', 0.46),
#                       ('abilityOther', 0.45),
#                       ('class', -0.43),
#                       ('nationalityOther', 0.43),
#                       ('isHomebound', -0.39),
#                       ('abilityWalking', 0.38),
#                       ('nationalityIrish', -0.36),
#                       ('abilityVision', 0.36),
#                       ('raceBlackOther', -0.34),
#                       ('numChildrenInHousehold', -0.33),
#                       ('racePakistani', -0.33),
#                       ('abilityCommunicating', 0.32),
#                       ('raceBlackAfrican', -0.32),
#                       ('abilityHearing', 0.22),
#                       ('nationalityWelsh', -0.2),
#                       ('nationalityBritish', 0.17),
#                       ('nationalityNorthIrish', -0.15),
#                       ('nationalityEnglish', -0.07),
#                       ('isRural', 0.06),
#                       ('isFemale', -0.05),
#                       ('age', -0.02),
#                       ('nationalityScottish', -0.02),
#                       ('raceBangladeshi', 0.02)],
#  'usesIpod': [('raceBlackCaribbean', 1.13),
#               ('raceMixedWhiteBlackAfrican', -0.97),
#               ('raceMixedWhiteBlackCaribbean', -0.96),
#               ('raceMixedWhiteAsian', -0.87),
#               ('raceMixedOther', -0.77),
#               ('raceIndian', -0.77),
#               ('nationalityNorthIrish', -0.76),
#               ('raceChinese', 0.74),
#               ('abilityReach', 0.68),
#               ('raceRefused', 0.68),
#               ('raceAsianOther', 0.67),
#               ('raceWhite', 0.62),
#               ('racePakistani', 0.54),
#               ('abilityCommunicating', -0.49),
#               ('abilityVision', -0.48),
#               ('raceMiddleEastern', 0.47),
#               ('abilityBreathless', 0.38),
#               ('abilityDyslexia', -0.37),
#               ('abilityHearing', 0.36),
#               ('nationalityOther', -0.33),
#               ('nationalityWelsh', 0.32),
#               ('isHomebound', -0.31),
#               ('raceBlackAfrican', 0.29),
#               ('class', -0.27),
#               ('nationalityEnglish', 0.27),
#               ('nationalityBritish', 0.23),
#               ('isRural', 0.21),
#               ('income', 0.21),
#               ('isRetired', 0.19),
#               ('raceOther', -0.17),
#               ('numChildrenInHousehold', -0.14),
#               ('nationalityIrish', 0.13),
#               ('householdSize', 0.11),
#               ('nationalityScottish', 0.1),
#               ('abilityMentalHealth', -0.1),
#               ('isFemale', -0.09),
#               ('abilityWheelchair', 0.08),
#               ('abilityOther', 0.06),
#               ('raceBangladeshi', 0.05),
#               ('raceBlackOther', -0.04),
#               ('age', -0.03),
#               ('abilityWalking', -0.02)],
#  'usesRadio': [('raceIndian', -1.03),
#                ('raceAsianOther', -0.89),
#                ('raceBangladeshi', 0.76),
#                ('raceWhite', 0.63),
#                ('raceMixedWhiteAsian', 0.52),
#                ('nationalityOther', -0.39),
#                ('abilityCommunicating', 0.35),
#                ('raceMiddleEastern', -0.34),
#                ('raceMixedOther', -0.33),
#                ('isRural', 0.32),
#                ('raceOther', -0.32),
#                ('abilityWheelchair', 0.3),
#                ('raceMixedWhiteBlackCaribbean', -0.3),
#                ('raceRefused', -0.28),
#                ('isRetired', 0.26),
#                ('abilityWalking', -0.25),
#                ('abilityVision', -0.24),
#                ('raceBlackOther', -0.24),
#                ('nationalityEnglish', 0.23),
#                ('nationalityNorthIrish', -0.18),
#                ('numChildrenInHousehold', -0.15),
#                ('nationalityScottish', 0.15),
#                ('abilityMentalHealth', 0.15),
#                ('raceBlackCaribbean', -0.15),
#                ('raceBlackAfrican', -0.14),
#                ('raceChinese', 0.14),
#                ('racePakistani', -0.13),
#                ('householdSize', 0.11),
#                ('class', -0.1),
#                ('abilityBreathless', 0.09),
#                ('abilityHearing', 0.09),
#                ('isFemale', -0.05),
#                ('age', 0.03),
#                ('isHomebound', 0.03),
#                ('income', 0.03),
#                ('abilityOther', 0.03),
#                ('nationalityBritish', -0.02),
#                ('nationalityWelsh', -0.01),
#                ('nationalityIrish', -0.01),
#                ('raceMixedWhiteBlackAfrican', 0.01),
#                ('abilityReach', -0.0),
#                ('abilityDyslexia', -0.0)],
#  'usesRadioDigital': [('abilityCommunicating', -1.34),
#                       ('raceMixedWhiteBlackAfrican', 0.92),
#                       ('raceBlackCaribbean', -0.9),
#                       ('raceBlackAfrican', -0.82),
#                       ('racePakistani', 0.76),
#                       ('raceWhite', 0.73),
#                       ('nationalityOther', -0.69),
#                       ('raceIndian', -0.65),
#                       ('raceMixedWhiteBlackCaribbean', -0.64),
#                       ('raceBangladeshi', 0.64),
#                       ('raceRefused', -0.64),
#                       ('raceMiddleEastern', -0.6),
#                       ('raceChinese', -0.58),
#                       ('raceAsianOther', -0.53),
#                       ('nationalityEnglish', 0.42),
#                       ('raceOther', 0.37),
#                       ('abilityMentalHealth', 0.36),
#                       ('abilityWheelchair', 0.33),
#                       ('nationalityScottish', 0.31),
#                       ('abilityVision', 0.29),
#                       ('raceMixedWhiteAsian', 0.29),
#                       ('abilityDyslexia', 0.28),
#                       ('raceBlackOther', 0.27),
#                       ('class', -0.24),
#                       ('income', 0.23),
#                       ('householdSize', 0.21),
#                       ('abilityBreathless', -0.21),
#                       ('nationalityNorthIrish', -0.18),
#                       ('abilityHearing', -0.15),
#                       ('raceMixedOther', 0.15),
#                       ('numChildrenInHousehold', -0.13),
#                       ('nationalityIrish', -0.13),
#                       ('abilityOther', -0.13),
#                       ('abilityWalking', 0.11),
#                       ('isRetired', -0.1),
#                       ('isFemale', -0.09),
#                       ('nationalityWelsh', 0.07),
#                       ('isRural', 0.06),
#                       ('abilityReach', -0.05),
#                       ('age', 0.02),
#                       ('isHomebound', -0.02),
#                       ('nationalityBritish', 0.01)],
#  'usesSmartSpeaker': [('raceChinese', -3.01),
#                       ('raceWhite', 1.45),
#                       ('nationalityOther', -1.1),
#                       ('raceOther', -1.08),
#                       ('raceBlackAfrican', 1.02),
#                       ('abilityOther', -0.79),
#                       ('raceIndian', -0.71),
#                       ('abilityDyslexia', 0.68),
#                       ('abilityMentalHealth', 0.65),
#                       ('abilityVision', 0.59),
#                       ('raceMixedWhiteAsian', -0.58),
#                       ('raceBangladeshi', 0.55),
#                       ('raceBlackCaribbean', 0.53),
#                       ('raceMixedWhiteBlackAfrican', 0.5),
#                       ('racePakistani', -0.49),
#                       ('nationalityBritish', 0.48),
#                       ('nationalityEnglish', 0.47),
#                       ('isRetired', -0.35),
#                       ('raceMixedWhiteBlackCaribbean', 0.35),
#                       ('class', -0.34),
#                       ('abilityReach', 0.32),
#                       ('raceMixedOther', 0.32),
#                       ('income', 0.31),
#                       ('isHomebound', -0.3),
#                       ('isRural', 0.26),
#                       ('nationalityIrish', -0.23),
#                       ('abilityCommunicating', -0.21),
#                       ('abilityHearing', 0.19),
#                       ('raceMiddleEastern', -0.17),
#                       ('householdSize', 0.16),
#                       ('isFemale', -0.16),
#                       ('raceBlackOther', 0.14),
#                       ('raceAsianOther', 0.12),
#                       ('nationalityScottish', 0.1),
#                       ('numChildrenInHousehold', 0.08),
#                       ('nationalityNorthIrish', 0.08),
#                       ('nationalityWelsh', -0.07),
#                       ('abilityWalking', -0.07),
#                       ('abilityBreathless', -0.03),
#                       ('age', -0.02),
#                       ('abilityWheelchair', 0.02),
#                       ('raceRefused', -0.0)],
#  'usesSmartWatch': [('raceChinese', -1.96),
#                     ('abilityWheelchair', 1.22),
#                     ('raceWhite', 1.19),
#                     ('raceMixedWhiteBlackAfrican', 0.82),
#                     ('raceMixedOther', 0.77),
#                     ('abilityVision', -0.76),
#                     ('raceBlackCaribbean', 0.73),
#                     ('abilityHearing', 0.71),
#                     ('raceBangladeshi', -0.71),
#                     ('raceMixedWhiteAsian', -0.7),
#                     ('abilityCommunicating', -0.69),
#                     ('nationalityNorthIrish', -0.66),
#                     ('isHomebound', -0.62),
#                     ('raceOther', -0.56),
#                     ('raceMixedWhiteBlackCaribbean', -0.54),
#                     ('raceAsianOther', 0.52),
#                     ('class', -0.42),
#                     ('raceIndian', -0.38),
#                     ('abilityBreathless', 0.36),
#                     ('abilityReach', -0.36),
#                     ('racePakistani', 0.32),
#                     ('raceBlackAfrican', 0.31),
#                     ('raceRefused', 0.28),
#                     ('income', 0.27),
#                     ('isRural', 0.23),
#                     ('abilityMentalHealth', 0.23),
#                     ('isFemale', -0.21),
#                     ('abilityOther', 0.2),
#                     ('nationalityIrish', 0.19),
#                     ('abilityDyslexia', 0.16),
#                     ('nationalityEnglish', 0.14),
#                     ('nationalityWelsh', 0.14),
#                     ('nationalityOther', 0.12),
#                     ('numChildrenInHousehold', 0.11),
#                     ('raceMiddleEastern', 0.11),
#                     ('isRetired', 0.1),
#                     ('raceBlackOther', 0.1),
#                     ('householdSize', 0.07),
#                     ('nationalityScottish', -0.07),
#                     ('abilityWalking', -0.06),
#                     ('age', -0.03),
#                     ('nationalityBritish', -0.01)],
#  'usesSmartphone': [('raceOther', 1.0),
#                     ('racePakistani', 0.89),
#                     ('raceMixedWhiteAsian', 0.81),
#                     ('isRetired', -0.79),
#                     ('raceMixedWhiteBlackCaribbean', 0.76),
#                     ('abilityMentalHealth', 0.75),
#                     ('raceMixedWhiteBlackAfrican', 0.65),
#                     ('class', -0.53),
#                     ('raceBlackAfrican', 0.5),
#                     ('raceBangladeshi', -0.48),
#                     ('isHomebound', -0.43),
#                     ('abilityBreathless', 0.41),
#                     ('raceWhite', -0.4),
#                     ('abilityVision', 0.38),
#                     ('abilityCommunicating', -0.37),
#                     ('abilityDyslexia', -0.33),
#                     ('nationalityScottish', 0.31),
#                     ('raceBlackOther', 0.29),
#                     ('income', 0.27),
#                     ('nationalityOther', -0.27),
#                     ('abilityOther', 0.27),
#                     ('raceAsianOther', -0.25),
#                     ('nationalityBritish', 0.24),
#                     ('raceRefused', -0.23),
#                     ('raceBlackCaribbean', 0.22),
#                     ('raceMiddleEastern', -0.22),
#                     ('raceChinese', -0.22),
#                     ('nationalityIrish', -0.2),
#                     ('abilityReach', -0.2),
#                     ('raceIndian', 0.15),
#                     ('abilityWheelchair', -0.12),
#                     ('isRural', -0.1),
#                     ('nationalityEnglish', 0.1),
#                     ('nationalityWelsh', 0.09),
#                     ('raceMixedOther', 0.09),
#                     ('age', -0.07),
#                     ('numChildrenInHousehold', 0.07),
#                     ('abilityHearing', 0.06),
#                     ('abilityWalking', -0.06),
#                     ('nationalityNorthIrish', 0.04),
#                     ('isFemale', 0.01),
#                     ('householdSize', -0.0)],
#  'usesTablet': [('raceRefused', -1.21),
#                 ('abilityCommunicating', -0.99),
#                 ('raceBangladeshi', 0.62),
#                 ('raceChinese', -0.58),
#                 ('abilityWheelchair', -0.56),
#                 ('raceBlackOther', 0.55),
#                 ('raceOther', 0.55),
#                 ('abilityMentalHealth', 0.54),
#                 ('isRetired', -0.4),
#                 ('class', -0.38),
#                 ('raceIndian', 0.37),
#                 ('abilityWalking', 0.36),
#                 ('abilityBreathless', 0.35),
#                 ('racePakistani', 0.33),
#                 ('nationalityOther', -0.29),
#                 ('raceBlackCaribbean', 0.29),
#                 ('abilityDyslexia', -0.28),
#                 ('income', 0.23),
#                 ('abilityHearing', -0.22),
#                 ('raceWhite', 0.22),
#                 ('raceMiddleEastern', -0.22),
#                 ('nationalityBritish', 0.21),
#                 ('abilityVision', -0.19),
#                 ('isHomebound', -0.17),
#                 ('raceMixedWhiteAsian', 0.16),
#                 ('abilityReach', -0.14),
#                 ('isFemale', 0.13),
#                 ('raceMixedWhiteBlackAfrican', -0.13),
#                 ('householdSize', 0.12),
#                 ('isRural', 0.09),
#                 ('abilityOther', 0.09),
#                 ('raceAsianOther', -0.08),
#                 ('nationalityEnglish', 0.06),
#                 ('raceMixedOther', 0.06),
#                 ('numChildrenInHousehold', 0.05),
#                 ('raceMixedWhiteBlackCaribbean', 0.04),
#                 ('nationalityScottish', 0.03),
#                 ('nationalityIrish', 0.03),
#                 ('raceBlackAfrican', -0.03),
#                 ('nationalityWelsh', 0.01),
#                 ('nationalityNorthIrish', -0.01),
#                 ('age', -0.0)]}
